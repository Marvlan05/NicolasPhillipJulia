# %%
using Plots

# %%
X = ["CB", "CBWS", "OBOTCB", "OB", "RT","PME","DBAT"];
Y = [576, 48, 240, 169, 36, 12, 72]
p = bar(X,Y,
xlabel = "Where Books Purchased", ylabel = "Frequency", label = "Where College Students Buy Textbooks")

# %%
X = ["Security", "Maintenance", "Flight Operations", "Hazardous materials", "Other",];
Y = [.43, .39, .06, .03, .09 ]
P = pie(X,Y, title = "Just How Safe Is That Jet?")
